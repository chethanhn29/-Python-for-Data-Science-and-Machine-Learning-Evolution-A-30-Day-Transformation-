# %%
numbers = [1, 2, 3, 4, 5, 6]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
# Out:
# [2, 4, 6]

# %%
map and filter are built-in functions in Python that are used to perform operations on sequences (lists, tuples, etc.).

map is a function that takes two or more arguments: a function and one or more sequences. It applies the function to each element of the sequences, and returns a new sequence with the results. The new sequence has the same length as the original sequences, and each element in the new sequence is the result of applying the function to the corresponding element in the original sequence.

For example, if you have a list of numbers and you want to double each number, you can use the map function:

scss
Copy code
numbers = [1, 2, 3, 4, 5]
result = list(map(lambda x: x * 2, numbers))
print(result)
Output:

csharp
Copy code
[2, 4, 6, 8, 10]
filter is a function that takes two arguments: a function and a sequence. It applies the function to each element in the sequence, and returns a new sequence with only the elements for which the function returns True.

For example, if you have a list of numbers and you want to get only the even numbers, you can use the filter function:

scss
Copy code
numbers = [1, 2, 3, 4, 5]
result = list(filter(lambda x: x % 2 == 0, numbers))
print(result)
Output:

csharp
Copy code
[2, 4]
Both map and filter can be used with any sequence type in Python, not just lists. They are useful for quickly transforming and manipulating sequences in a functional programming style.




chethu hn
can u name some of the inbuilt functions like map and filter
Yes, here are some built-in functions in Python that are similar to map and filter:

reduce: This function is used to apply a binary function to the elements of a sequence, reducing the sequence to a single value. It's part of the functools module, so you need to import it before using it.

zip: This function is used to combine two or more sequences into a single sequence of tuples, where each tuple contains the n-th elements from each of the input sequences.

enumerate: This function is used to generate a sequence of tuples, where each tuple contains the index of an element and the element itself.

sorted: This function is used to sort a sequence. It returns a new list with the elements of the original sequence sorted in ascending order by default.

reversed: This function is used to reverse a sequence. It returns a new sequence with the elements of the original sequence in reverse order.

any and all: These functions are used to check if any or all elements of a sequence are True, respectively.

These are just a few examples of built-in functions in Python that are similar to map and filter. There are many other functions available in Python, each with its own specific use case.




chethu hn
give me all about filter function 
The filter function is a built-in function in Python that is used to filter elements from a sequence (list, tuple, etc.) based on a given condition. It takes two arguments: a function and a sequence. The function is used to evaluate each element in the sequence, and only the elements for which the function returns True are included in the resulting sequence.

Here's the syntax for using the filter function:

scss
Copy code
filter(function, sequence)
Where function is a function that takes a single argument and returns a Boolean value (True or False), and sequence is the input sequence that you want to filter. The filter function returns an iterator, so you can use the list or tuple function to convert the result to a list or tuple, respectively.

Here's an example that uses the filter function to extract the even numbers from a list:

scss
Copy code
numbers = [1, 2, 3, 4, 5, 6]
result = list(filter(lambda x: x % 2 == 0, numbers))
print(result)
Output:

csharp
Copy code
[2, 4, 6]
In this example, the lambda function lambda x: x % 2 == 0 returns True if the input number is even and False if the input number is odd. The filter function applies this function to each element in the numbers list, and only the elements for which the function returns True are included in the resulting list.

Note that the filter function works with any sequence type in Python, not just lists. Additionally, you can use any function as the input function, not just a lambda function. The function just needs to take a single argument and return a Boolean value.




chethu hn
can you give me 10 examples for above topics
Sure! Here are 10 examples that demonstrate the use of map and filter functions in Python:

Using map to double the numbers in a list:
scss
Copy code
numbers = [1, 2, 3, 4, 5]
doubled_numbers = list(map(lambda x: x * 2, numbers))
print(doubled_numbers)
Output: [2, 4, 6, 8, 10]

Using filter to extract even numbers from a list:
scss
Copy code
numbers = [1, 2, 3, 4, 5, 6]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
Output: [2, 4, 6]

Using map to convert a list of strings to uppercase:
scss
Copy code
words = ['apple', 'banana', 'cherry']
uppercase_words = list(map(lambda x: x.upper(), words))
print(uppercase_words)
Output: ['APPLE', 'BANANA', 'CHERRY']

Using filter to extract words that contain the letter 'a' from a list:
scss
Copy code
words = ['apple', 'banana', 'cherry']
words_with_a = list(filter(lambda x: 'a' in x, words))
print(words_with_a)
Output: ['apple', 'banana']

Using map and filter together to extract and double even numbers from a list:
python
Copy code
numbers = [1, 2, 3, 4, 5, 6]
even_doubled_numbers = list(map(lambda x: x * 2, filter(lambda x: x % 2 == 0, numbers)))
print(even_doubled_numbers)
Output: [4, 8, 12]

Using map to square the numbers in a list:
scss
Copy code
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x ** 2, numbers))
print(squared_numbers)
Output: [1, 4, 9, 16, 25]

Using filter to extract numbers that are divisible by 3 from a list:
scss
Copy code
numbers = [1, 2, 3, 4, 5, 6]
numbers_divisible_by_3 = list(filter(lambda x: x % 3 == 0, numbers))
print(numbers_divisible_by_3)
Output: [3, 6]

Using map to convert a list of temperatures from Celsius to Fahrenheit:
scss
Copy code
temperatures_celsius = [0, 10, 20, 30, 40]
temperatures_fahrenheit = list(map(lambda x: x * 9/5 + 32, temperatures_celsius))
print(temperatures_fahrenheit)
Output: [32.0, 50.0, 68.0, 86.0, 104.0]

Using filter to extract positive numbers from a list:
``



chethu hn
give me all about reduce functions eith 1 rxamples
The reduce function is a built-in function in the functools module in Python that takes a function and a sequence as input and applies the function cumulatively to the elements of the sequence. In other words, it successively applies the function to the elements of the sequence and accumulates the result.

Here's an example of using the reduce function to find the product of all the numbers in a list:

scss
Copy code
from functools import reduce

numbers = [1, 2, 3, 4, 5]
product = reduce(lambda x, y: x * y, numbers)
print(product)
Output: 120

In this example, the reduce function takes a lambda function that multiplies two numbers, and a list of numbers. It starts by multiplying the first two elements of the list (1 * 2), then multiplies the result by the next element (2 * 3), and so on, until all elements have been processed. The final result is the product of all the numbers in the list.




chethu hn
give me 10 examples on reduce function
Sure! Here are 10 examples of using the reduce function in Python:

Finding the product of all numbers in a list:
scss
Copy code
from functools import reduce

numbers = [1, 2, 3, 4, 5]
product = reduce(lambda x, y: x * y, numbers)
print(product)
Output: 120

Calculating the sum of squares of all numbers in a list:
scss
Copy code
from functools import reduce

numbers = [1, 2, 3, 4, 5]
sum_of_squares = reduce(lambda x, y: x + y ** 2, numbers, 0)
print(sum_of_squares)
Output: 55

Finding the maximum number in a list:
python
Copy code
from functools import reduce

numbers = [1, 2, 3, 4, 5]
maximum = reduce(lambda x, y: x if x > y else y, numbers)
print(maximum)
Output: 5

Finding the minimum number in a list:
python
Copy code
from functools import reduce

numbers = [1, 2, 3, 4, 5]
minimum = reduce(lambda x, y: x if x < y else y, numbers)
print(minimum)
Output: 1

Calculating the factorial of a number:
python
Copy code
from functools import reduce

number = 5
factorial = reduce(lambda x, y: x * y, range(1, number + 1))
print(factorial)
Output: 120

Concatenating all elements in a list of strings:
python
Copy code
from functools import reduce

words = ['apple', 'banana', 'cherry']
sentence = reduce(lambda x, y: x + ' ' + y, words)
print(sentence)
Output: 'apple banana cherry'

Flattening a list of lists:
scss
Copy code
from functools import reduce

lists = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
flat_list = reduce(lambda x, y: x + y, lists)
print(flat_list)
Output: [1, 2, 3, 4, 5, 6, 7, 8, 9]

Counting the number of occurrences of a word in a list:
python
Copy code
from functools import reduce

words = ['apple', 'banana', 'cherry', 'apple']
word_to_count = 'apple'
count = reduce(lambda x, y: x + (1 if y == word_to_count else 0), words, 0)
print(count)
Output: 2

Calculating the dot product of two lists:
scss
Copy code
from functools import reduce

list1 = [1, 2, 3]
list2 = [4, 5, 6]
dot_product = reduce(lambda x, y: x + y[0] * y[1], zip(list1, list2), 0)
print(dot_product)
Output: 32

Finding the longest word in a list
# Out:
#   File "C:\Users\Chethan\AppData\Local\Temp\ipykernel_1264\3491511800.py", line 2
#     even_numbers = [x for x if i%2==0 in numbers ]
#                                                  ^
# SyntaxError: invalid syntax
